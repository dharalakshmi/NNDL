# %% [markdown]
# <a href="https://colab.research.google.com/github/dharalakshmi/NNDL/blob/main/Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras,os
from keras.datasets import fashion_mnist, cifar100
from keras.layers import Dense, Activation, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization
from keras.models import Sequential
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
from keras import optimizers
from tensorflow.keras.layers import Lambda
from keras import backend as K
from keras import regularizers
from sklearn import datasets # load dataset
from sklearn.model_selection import train_test_split # split dataset
from sklearn.preprocessing import StandardScaler # standard scaler
from sklearn.metrics import accuracy_score # check accuracy

# %%
(train_X,train_Y), (test_X,test_Y) = fashion_mnist.load_data()
train_X = train_X.reshape(-1, 28,28, 1)
test_X = test_X.reshape(-1, 28,28, 1)
train_X = train_X.astype('float32')
test_X = test_X.astype('float32')
train_X = train_X / 255
test_X = test_X / 255
train_X1 = train_X[0:100]
train_Y1 = train_Y[:100]
val_X = train_X[100:150]
val_Y_Onehot = to_categorical(train_Y[100:150])
train_Y_one_hot = to_categorical(train_Y1)
test_Y_one_hot = to_categorical(test_Y)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 9us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 53s 2us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 7s 2us/step

# %%
model = Sequential()
model.add(Conv2D(64, (3,3), input_shape=(28, 28, 1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64, (3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(64))
model.add(Dense(10))
model.add(Activation('softmax'))
model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(),metrics=['accuracy'])
model.summary()
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 26, 26, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 11, 11, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       102,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 10)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 140,682 (549.54 KB)
#  Trainable params: 140,682 (549.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_X1, train_Y_one_hot, batch_size=64, epochs=100, validation_data=(val_X,val_Y_Onehot))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.show()
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 232ms/step - accuracy: 0.1165 - loss: 2.3060 - val_accuracy: 0.0400 - val_loss: 2.2775
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.1958 - loss: 2.1376 - val_accuracy: 0.1200 - val_loss: 2.2345
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.2900 - loss: 1.9997 - val_accuracy: 0.2200 - val_loss: 2.1592
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.4458 - loss: 1.8286 - val_accuracy: 0.3800 - val_loss: 2.0057
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5252 - loss: 1.6217 - val_accuracy: 0.5600 - val_loss: 1.7738
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6877 - loss: 1.3599 - val_accuracy: 0.5400 - val_loss: 1.5624
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7462 - loss: 1.1583 - val_accuracy: 0.4800 - val_loss: 1.3299
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7010 - loss: 0.9906 - val_accuracy: 0.6200 - val_loss: 1.0745
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7723 - loss: 0.8337 - val_accuracy: 0.7200 - val_loss: 0.9475
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7381 - loss: 0.7640 - val_accuracy: 0.6600 - val_loss: 0.9590
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8042 - loss: 0.6192 - val_accuracy: 0.5800 - val_loss: 1.0181
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7738 - loss: 0.5818 - val_accuracy: 0.7000 - val_loss: 0.8696
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8294 - loss: 0.5401 - val_accuracy: 0.7200 - val_loss: 0.7852
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8583 - loss: 0.4581 - val_accuracy: 0.6600 - val_loss: 0.7738
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8108 - loss: 0.4543 - val_accuracy: 0.7400 - val_loss: 0.7924
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8702 - loss: 0.4094 - val_accuracy: 0.6800 - val_loss: 0.8192
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8650 - loss: 0.3943 - val_accuracy: 0.7200 - val_loss: 0.7677
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8375 - loss: 0.4021 - val_accuracy: 0.6800 - val_loss: 0.7817
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8583 - loss: 0.3251 - val_accuracy: 0.7400 - val_loss: 0.7135
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8679 - loss: 0.2888 - val_accuracy: 0.7400 - val_loss: 0.6846
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8888 - loss: 0.2690 - val_accuracy: 0.7600 - val_loss: 0.6501
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8954 - loss: 0.2357 - val_accuracy: 0.8000 - val_loss: 0.6328
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9140 - loss: 0.2344 - val_accuracy: 0.8000 - val_loss: 0.6277
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9340 - loss: 0.2303 - val_accuracy: 0.8000 - val_loss: 0.5691
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9444 - loss: 0.2019 - val_accuracy: 0.7800 - val_loss: 0.5811
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9273 - loss: 0.1854 - val_accuracy: 0.8000 - val_loss: 0.5743
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9444 - loss: 0.1725 - val_accuracy: 0.8000 - val_loss: 0.6068
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9392 - loss: 0.1725 - val_accuracy: 0.8200 - val_loss: 0.5807
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9510 - loss: 0.1547 - val_accuracy: 0.7400 - val_loss: 0.5628
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9696 - loss: 0.1299 - val_accuracy: 0.8200 - val_loss: 0.5567
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9696 - loss: 0.1376 - val_accuracy: 0.8200 - val_loss: 0.5669
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9458 - loss: 0.1397 - val_accuracy: 0.8200 - val_loss: 0.5986
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9577 - loss: 0.1412 - val_accuracy: 0.8200 - val_loss: 0.5611
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9748 - loss: 0.1021 - val_accuracy: 0.8400 - val_loss: 0.5558
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9762 - loss: 0.1082 - val_accuracy: 0.8000 - val_loss: 0.5485
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9933 - loss: 0.0880 - val_accuracy: 0.8000 - val_loss: 0.5529
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9867 - loss: 0.0776 - val_accuracy: 0.7800 - val_loss: 0.5628
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9881 - loss: 0.0839 - val_accuracy: 0.8000 - val_loss: 0.5416
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9867 - loss: 0.0778 - val_accuracy: 0.7800 - val_loss: 0.5413
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9933 - loss: 0.0632 - val_accuracy: 0.8200 - val_loss: 0.5787
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9762 - loss: 0.0747 - val_accuracy: 0.8000 - val_loss: 0.5837
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9933 - loss: 0.0695 - val_accuracy: 0.8000 - val_loss: 0.5626
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0678 - val_accuracy: 0.7800 - val_loss: 0.5677
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9881 - loss: 0.0555 - val_accuracy: 0.7400 - val_loss: 0.5829
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0451 - val_accuracy: 0.8000 - val_loss: 0.5703
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0523 - val_accuracy: 0.8200 - val_loss: 0.5637
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9881 - loss: 0.0470 - val_accuracy: 0.8000 - val_loss: 0.5846
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0440 - val_accuracy: 0.8000 - val_loss: 0.6188
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0458 - val_accuracy: 0.8000 - val_loss: 0.5768
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0356 - val_accuracy: 0.8000 - val_loss: 0.6006
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0438 - val_accuracy: 0.8000 - val_loss: 0.6267
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0396 - val_accuracy: 0.8000 - val_loss: 0.6227
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0328 - val_accuracy: 0.8200 - val_loss: 0.6356
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9881 - loss: 0.0355 - val_accuracy: 0.8000 - val_loss: 0.6315
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0219 - val_accuracy: 0.7800 - val_loss: 0.6282
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0254 - val_accuracy: 0.7800 - val_loss: 0.6478
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0245 - val_accuracy: 0.7800 - val_loss: 0.6484
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0194 - val_accuracy: 0.7800 - val_loss: 0.6521
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0189 - val_accuracy: 0.7800 - val_loss: 0.6614
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0170 - val_accuracy: 0.7600 - val_loss: 0.6809
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0181 - val_accuracy: 0.7800 - val_loss: 0.6793
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 0.8200 - val_loss: 0.6512
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0169 - val_accuracy: 0.8200 - val_loss: 0.6601
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0161 - val_accuracy: 0.8000 - val_loss: 0.6952
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 0.8000 - val_loss: 0.7120
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.7800 - val_loss: 0.7204
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.7800 - val_loss: 0.7405
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0122 - val_accuracy: 0.7800 - val_loss: 0.7312
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 0.8000 - val_loss: 0.7199
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.8000 - val_loss: 0.7156
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.8000 - val_loss: 0.7230
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.7800 - val_loss: 0.7434
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.8000 - val_loss: 0.7583
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.8000 - val_loss: 0.7263
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.8000 - val_loss: 0.7356
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.7600 - val_loss: 0.7740
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.7600 - val_loss: 0.8012
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.7600 - val_loss: 0.7786
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.7800 - val_loss: 0.7732
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.7600 - val_loss: 0.7869
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.7800 - val_loss: 0.8289
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.7800 - val_loss: 0.8338
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.7600 - val_loss: 0.8253
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.7800 - val_loss: 0.8241
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.7800 - val_loss: 0.8251
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.7600 - val_loss: 0.8264
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.7600 - val_loss: 0.8375
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.7600 - val_loss: 0.8517
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.7600 - val_loss: 0.8615
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.7600 - val_loss: 0.8659
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.7600 - val_loss: 0.8705
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.7600 - val_loss: 0.8681
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.7600 - val_loss: 0.8672
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.7600 - val_loss: 0.8763
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.7600 - val_loss: 0.8929
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.7600 - val_loss: 0.8970
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.7600 - val_loss: 0.8915
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.7600 - val_loss: 0.8877
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.7600 - val_loss: 0.8923
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.7600 - val_loss: 0.9068

# %%
#Evaluate the model on the test data after training your model
score = model.evaluate(test_X[0:100],test_Y_one_hot[0:100], verbose=1)
print('\nKeras CNN binary accuracy:', score[1],'\n')
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6845 - loss: 1.7516
#
# Keras CNN binary accuracy: 0.6800000071525574

# %%
filters, biases = model.layers[0].get_weights()
for i in range(5):
 plt.imshow(filters[:,:,0,i], cmap='gray')
 plt.show()

# %%
filt = filters[:, :, 0, 1]

# %%
from scipy import signal

# Select an input image from the training set
im = train_X[10].reshape(28, 28)

# Display the original image
plt.imshow(im, cmap='gray')
plt.title('Original Image')
plt.show()

# Apply the filter using 2D convolution
ot = signal.convolve2d(im, filt, boundary='symm', mode='same')

# Display the output of the convolution
plt.imshow(ot, cmap='gray')
plt.title('Output after Convolution')
plt.show()
